# %% [markdown]
# # Pipeline to process medical reports
#
# In this notebook, we will walkthrough on how to build a pipeline that will process medical reports in PDF format to extract relevant medical information by using the following AWS services:
#
# - [Textract](https://aws.amazon.com/textract/): To extract text from the PDF medical report
# - [Comprehend Medical](https://aws.amazon.com/comprehend/medical/): To extract relevant medical information from the output of textract

# %%
import boto3
import time
import sagemaker
import os 
from trp import Document

bucket = sagemaker.Session().default_bucket()
prefix = 'sagemaker/medical_notes'

# %% [markdown]
# ## Process PDF with Amazon Textract

# %% [markdown]
# In this section, we will be using Amazon Textract to extract text from a sample PDF medical record. If you're interested, you can preview the PDF report in the reports directory.
#
# Amazon Textract can detect and analyze text in both single page and multi page documents. Single page document analysis can be performed using a Textract synchronous operation. However, multi page processing is an asynchronous operation. In this lab, we will be processing our medical report using the multi page processing method.
#
# For more information on single page and multi page document processing, please refer to the following link:
#
# - Single Page Processing: https://docs.aws.amazon.com/textract/latest/dg/sync.html
# - Multi Page Processing: https://docs.aws.amazon.com/textract/latest/dg/async.html
#
# As we are using the multi page textract operation, we will need to need upload our sample medical record to an S3 bucket. Run the next cell to upload our sample medical report.

# %%
fileName =  'sample_report_1.pdf'
fileUploadPath = os.path.join('./data', fileName)
textractObjectName = os.path.join(prefix, 'data', fileName)

# Upload medical report file
boto3.Session().resource('s3').Bucket(bucket).Object(textractObjectName).upload_file(fileUploadPath)

# %% [markdown]
# In the next step, we will start the asynchronous textract operation by calling the `start_document_analysis()` function. The function will kickoff an asynchronous job that will process our medical report file in the stipulated S3 bucket.

# %%
client = boto3.client('textract')
response = client.start_document_analysis(
    DocumentLocation={
        'S3Object': {
            'Bucket': bucket,
            'Name': textractObjectName
        }},
    FeatureTypes=[
        'TABLES',
    ]
    )

textractJobId = response["JobId"]

# %% [markdown]
# As the job is kicked off in the background, we can monitor the progress of the job by calling the `get_document_analysis()` function and passing the job id of the job that we created.
#
# Run the next cell and wait for the Textract Job status to return a SUCCEEDED status.

# %%
time.sleep(5)
response = client.get_document_analysis(JobId=textractJobId)
status = response["JobStatus"]
# print("Job status: {}".format(status))

while(status == "IN_PROGRESS"):
    time.sleep(5)
    response = client.get_document_analysis(JobId=textractJobId)
    status = response["JobStatus"]
    print("Textract Job status: {}".format(status))
# Out:
# Textract Job status: IN_PROGRESS
# Textract Job status: IN_PROGRESS
# Textract Job status: IN_PROGRESS
# Textract Job status: IN_PROGRESS
# Textract Job status: IN_PROGRESS
# Textract Job status: IN_PROGRESS
# Textract Job status: IN_PROGRESS
# Textract Job status: IN_PROGRESS
# Textract Job status: IN_PROGRESS
# Textract Job status: IN_PROGRESS
# Textract Job status: SUCCEEDED

# %% [markdown]
# Now that we've successfully extracted the text from the medical report, let us extract the textract results and consolidate the text so that we can pass it to Comprehend Medical to start extract medical information from the report.

# %%
pages = []

time.sleep(5)

response = client.get_document_analysis(JobId=textractJobId)

pages.append(response)
print("Resultset page recieved: {}".format(len(pages)))
nextToken = None
if('NextToken' in response):
    nextToken = response['NextToken']

while(nextToken):
    time.sleep(5)

    response = client.get_document_analysis(JobId=textractJobId, NextToken=nextToken)

    pages.append(response)
    print("Resultset page recieved: {}".format(len(pages)))
    nextToken = None
    if('NextToken' in response):
        nextToken = response['NextToken']

# Format the response from textract using the trp Document library
doc = Document(pages)
# Out:
# Resultset page recieved: 1

# %% [markdown]
# ## Extract medical information with Amazon Comprehend Medical
#
# In the following section, we will be using Amazon Comprehend Medical to extract medical information from the text we got from the Textract operation on the PDF medical report.
#
# With Amazon Comprehend Medical, you can perform the following on your documents:
#
# - [Detect Entities (Version 2)](https://docs.aws.amazon.com/comprehend/latest/dg/extracted-med-info-V2.html) - Examine unstructured clinical text to detect textual references to medical information such as medical condition, treatment, tests and results, and medications. This version uses a new model and changes the way some entities are returned in the output. For more information, see [DetectEntitiesV2](https://docs.aws.amazon.com/comprehend/latest/dg/API_medical_DetectEntitiesV2.html).
#
# - [Detect PHI](https://docs.aws.amazon.com/comprehend/latest/dg/how-medical-phi.html) —Examine unstructured clinical text to detect textual references to protected health information (PHI) such as names and addresses.
#
#
# In this lab, we will be using the detect entities function to extract the medical condition. In the following cell, we will be processing the text on each page in batches of 20,000 UTF-8 characters. This is because Comprehend Medical has a maximum document size of 20,000 bytes (reference: https://docs.aws.amazon.com/comprehend/latest/dg/guidelines-and-limits-med.html). Once we've processed the text, we will then stich up the response into a into a single variable where we can either save to a csv or use for our analysis.

# %%
maxLength=20000

comprehendResponse = []

for page in doc.pages:
    pageText = page.text
    comprehend_medical_client = boto3.client(service_name='comprehendmedical', region_name='ap-southeast-2')
    for i in range(0, len(pageText), maxLength):
        response = comprehend_medical_client.detect_entities_v2(Text=pageText[0+i:maxLength+i])
        comprehendResponse.append(response)

# %%
# Ouput
comprehendResponse
# Out:
# [{'Entities': [{'Id': 2,
#     'BeginOffset': 23,
#     'EndOffset': 35,
#     'Score': 0.9898292422294617,
#     'Text': 'Terri Hodosy',
#     'Category': 'PROTECTED_HEALTH_INFORMATION',
#     'Type': 'NAME',
#     'Traits': []},
#    {'Id': 3,
#     'BeginOffset': 47,
#     'EndOffset': 57,
#     'Score': 0.9998424053192139,
#     'Text': '10/22/1962',
#     'Category': 'PROTECTED_HEALTH_INFORMATION',
#     'Type': 'DATE',
#     'Traits': []},
#    {'Id': 4,
#     'BeginOffset': 102,
#     'EndOffset': 112,
#     'Score': 0.9999436140060425,
#     'Text': '01/01/2020',
#     'Category': 'PROTECTED_HEALTH_INFORMATION',
#     'Type': 'DATE',
#     'Traits': []},
#    {'Id': 5,
#     'BeginOffset': 128,
#     'EndOffset': 138,
#     'Score': 0.9998565912246704,
#     'Text': '01/20/2020',
#     'Category': 'PROTECTED_HEALTH_INFORMATION',
#     'Type': 'DATE',
#     'Traits': []},
#    {'Id': 6,
#     'BeginOffset': 165,
#     'EndOffset': 167,
#     'Score': 0.9463181495666504,
#     'Text': '15',
#     'Category': 'PROTECTED_HEALTH_INFORMATION',
#     'Type': 'AGE',
#     'Traits': []},
#    {'Id': 7,
#     'BeginOffset': 195,
#     'EndOffset': 214,
#     'Score': 0.9422523379325867,
#     'Text': "Children's Hospital",
#     'Category': 'PROTECTED_HEALTH_INFORMATION',
#     'Type': 'ADDRESS',
#     'Traits': []},
#    {'Id': 8,
#     'BeginOffset': 245,
#     'EndOffset': 265,
#     'Score': 0.9977983832359314,
#     'Text': 'Emergency Department',
#     'Category': 'PROTECTED_HEALTH_INFORMATION',
#     'Type': 'ADDRESS',
#     'Traits': []},
#    {'Id': 34,
#     'BeginOffset': 437,
#     'EndOffset': 443,
#     'Score': 0.8445239067077637,
#     'Text': 'day of',
#     'Category': 'TIME_EXPRESSION',
#     'Type': 'TIME_TO_DX_NAME',
#     'Traits': [],
#     'Attributes': [{'Type': 'DX_NAME',
#       'Score': 0.3701491951942444,
#       'RelationshipScore': 0.7084896564483643,
#       'RelationshipType': 'OVERLAP',
#       'Id': 0,
#       'BeginOffset': 462,
#       'EndOffset': 488,
#       'Text': 'jelly-like red-brown stool',
#       'Category': 'MEDICAL_CONDITION',
#       'Traits': [{'Name': 'SYMPTOM', 'Score': 0.8496387004852295}]}]},
#    {'Id': 0,
#     'BeginOffset': 462,
#     'EndOffset': 488,
#     'Score': 0.3701491951942444,
#     'Text': 'jelly-like red-brown stool',
#     'Category': 'MEDICAL_CONDITION',
#     'Type': 'DX_NAME',
#     'Traits': [{'Name': 'SYMPTOM', 'Score': 0.8496387004852295}]},
#    {'Id': 35,
#     'BeginOffset': 500,
#     'EndOffset': 515,
#     'Score': 0.9540578722953796,
#     'Text': 'Tuesday morning',
#     'Category': 'TIME_EXPRESSION',
#     'Type': 'TIME_TO_DX_NAME',
#     'Traits': [],
#     'Attributes': [{'Type': 'DX_NAME',
#       'Score': 0.3701491951942444,
#       'RelationshipScore': 0.9801689386367798,
#       'RelationshipType': 'OVERLAP',
#       'Id': 0,
#       'BeginOffset': 462,
#       'EndOffset': 488,
#       'Text': 'jelly-like red-brown stool',
#       'Category': 'MEDICAL_CONDITION',
#       'Traits': [{'Name': 'SYMPTOM', 'Score': 0.8496387004852295}]}]},
#    {'Id': 1,
#     'BeginOffset': 548,
#     'EndOffset': 553,
#     'Score': 0.688994288444519,
#     'Text': 'vomit',
#     'Category': 'MEDICAL_CONDITION',
#     'Type': 'DX_NAME',
#     'Traits': []},
#    {'Id': 9,
#     'BeginOffset': 660,
#     'EndOffset': 682,
#     'Score': 0.9982219338417053,
#     'Text': 'white blood cell count',
#     'Category': 'TEST_TREATMENT_PROCEDURE',
#     'Type': 'TEST_NAME',
#     'Traits': [],
#     'Attributes': [{'Type': 'TEST_VALUE',
#       'Score': 0.8200131058692932,
#       'RelationshipScore': 0.9999998807907104,
#       'RelationshipType': 'TEST_VALUE',
#       'Id': 10,
#       'BeginOffset': 683,
#       'EndOffset': 691,
#       'Text': 'elevated',
#       'Category': 'TEST_TREATMENT_PROCEDURE',
#       'Traits': []},
#      {'Type': 'TEST_VALUE',
#       'Score': 0.9945077300071716,
#       'RelationshipScore': 1.0,
#       'RelationshipType': 'TEST_VALUE',
#       'Id': 11,
#       'BeginOffset': 695,
#       'EndOffset': 699,
#       'Text': '22.2',
#       'Category': 'TEST_TREATMENT_PROCEDURE',
#       'Traits': []}]},
#    {'Id': 12,
#     'BeginOffset': 701,
#     'EndOffset': 711,
#     'Score': 0.9990515112876892,
#     'Text': 'hemoglobin',
#     'Category': 'TEST_TREATMENT_PROCEDURE',
#     'Type': 'TEST_NAME',
#     'Traits': [],
#     'Attributes': [{'Type': 'TEST_VALUE',
#       'Score': 0.9998207688331604,
#       'RelationshipScore': 0.9999722242355347,
#       'RelationshipType': 'TEST_VALUE',
#       'Id': 13,
#       'BeginOffset': 712,
#       'EndOffset': 716,
#       'Text': '14.1',
#       'Category': 'TEST_TREATMENT_PROCEDURE',
#       'Traits': []}]},
#    {'Id': 14,
#     'BeginOffset': 718,
#     'EndOffset': 724,
#     'Score': 0.9996381998062134,
#     'Text': 'sodium',
#     'Category': 'TEST_TREATMENT_PROCEDURE',
#     'Type': 'TEST_NAME',
#     'Traits': [],
#     'Attributes': [{'Type': 'TEST_VALUE',
#       'Score': 0.9996167421340942,
#       'RelationshipScore': 0.9999411106109619,
#       'RelationshipType': 'TEST_VALUE',
#       'Id': 15,
#       'BeginOffset': 725,
#       'EndOffset': 728,
#       'Text': '138',
#       'Category': 'TEST_TREATMENT_PROCEDURE',
#       'Traits': []}]},
#    {'Id': 16,
#     'BeginOffset': 730,
#     'EndOffset': 739,
#     'Score': 0.9998087286949158,
#     'Text': 'potassium',
#     'Category': 'TEST_TREATMENT_PROCEDURE',
#     'Type': 'TEST_NAME',
#     'Traits': [],
#     'Attributes': [{'Type': 'TEST_VALUE',
#       'Score': 0.9997764229774475,
#       'RelationshipScore': 0.9999998807907104,
#       'RelationshipType': 'TEST_VALUE',
#       'Id': 17,
#       'BeginOffset': 740,
#       'EndOffset': 743,
#       'Text': '7.2',
#       'Category': 'TEST_TREATMENT_PROCEDURE',
#       'Traits': []},
#      {'Type': 'TEST_VALUE',
#       'Score': 0.398907333612442,
#       'RelationshipScore': 0.9999532699584961,
#       'RelationshipType': 'TEST_VALUE',
#       'Id': 18,
#       'BeginOffset': 754,
#       'EndOffset': 763,
#       'Text': 'hemolyzed',
#       'Category': 'TEST_TREATMENT_PROCEDURE',
#       'Traits': []}]},
#    {'Id': 19,
#     'BeginOffset': 765,
#     'EndOffset': 773,
#     'Score': 0.9996203184127808,
#     'Text': 'chloride',
#     'Category': 'TEST_TREATMENT_PROCEDURE',
#     'Type': 'TEST_NAME',
#     'Traits': [],
#     'Attributes': [{'Type': 'TEST_VALUE',
#       'Score': 0.9996695518493652,
#       'RelationshipScore': 0.9999980926513672,
#       'RelationshipType': 'TEST_VALUE',
#       'Id': 20,
#       'BeginOffset': 774,
#       'EndOffset': 777,
#       'Text': '107',
#       'Category': 'TEST_TREATMENT_PROCEDURE',
#       'Traits': []}]},
#    {'Id': 21,
#     'BeginOffset': 779,
#     'EndOffset': 782,
#     'Score': 0.9997187256813049,
#     'Text': 'CO2',
#     'Category': 'TEST_TREATMENT_PROCEDURE',
#     'Type': 'TEST_NAME',
#     'Traits': [],
#     'Attributes': [{'Type': 'TEST_VALUE',
#       'Score': 0.9996893405914307,
#       'RelationshipScore': 0.9999998807907104,
#       'RelationshipType': 'TEST_VALUE',
#       'Id': 22,
#       'BeginOffset': 783,
#       'EndOffset': 785,
#       'Text': '23',
#       'Category': 'TEST_TREATMENT_PROCEDURE',
#       'Traits': []}]},
#    {'Id': 23,
#     'BeginOffset': 787,
#     'EndOffset': 790,
#     'Score': 0.999881386756897,
#     'Text': 'BUN',
#     'Category': 'TEST_TREATMENT_PROCEDURE',
#     'Type': 'TEST_NAME',
#     'Traits': [],
#     'Attributes': [{'Type': 'TEST_VALUE',
#       'Score': 0.9996979236602783,
#       'RelationshipScore': 0.9999998807907104,
#       'RelationshipType': 'TEST_VALUE',
#       'Id': 24,
#       'BeginOffset': 791,
#       'EndOffset': 793,
#       'Text': '17',
#       'Category': 'TEST_TREATMENT_PROCEDURE',
#       'Traits': []}]},
#    {'Id': 25,
#     'BeginOffset': 795,
#     'EndOffset': 805,
#     'Score': 0.9996693134307861,
#     'Text': 'creatinine',
#     'Category': 'TEST_TREATMENT_PROCEDURE',
#     'Type': 'TEST_NAME',
#     'Traits': [],
#     'Attributes': [{'Type': 'TEST_VALUE',
#       'Score': 0.9995694756507874,
#       'RelationshipScore': 0.9999980926513672,
#       'RelationshipType': 'TEST_VALUE',
#       'Id': 26,
#       'BeginOffset': 806,
#       'EndOffset': 809,
#       'Text': '1.2',
#       'Category': 'TEST_TREATMENT_PROCEDURE',
#       'Traits': []}]},
#    {'Id': 27,
#     'BeginOffset': 815,
#     'EndOffset': 822,
#     'Score': 0.9888295531272888,
#     'Text': 'glucose',
#     'Category': 'TEST_TREATMENT_PROCEDURE',
#     'Type': 'TEST_NAME',
#     'Traits': [],
#     'Attributes': [{'Type': 'TEST_VALUE',
#       'Score': 0.9835261702537537,
#       'RelationshipScore': 0.9999990463256836,
#       'RelationshipType': 'TEST_VALUE',
#       'Id': 28,
#       'BeginOffset': 826,
#       'EndOffset': 828,
#       'Text': '50',
#       'Category': 'TEST_TREATMENT_PROCEDURE',
#       'Traits': []}]},
#    {'Id': 29,
#     'BeginOffset': 911,
#     'EndOffset': 923,
#     'Score': 0.7875098586082458,
#     'Text': 'barium enema',
#     'Category': 'TEST_TREATMENT_PROCEDURE',
#     'Type': 'TEST_NAME',
#     'Traits': []},
#    {'Id': 48,
#     'BeginOffset': 1003,
#     'EndOffset': 1022,
#     'Score': 0.9972665309906006,
#     'Text': "Children's Hospital",
#     'Category': 'PROTECTED_HEALTH_INFORMATION',
#     'Type': 'ADDRESS',
#     'Traits': []},
#    {'Id': 36,
#     'BeginOffset': 1073,
#     'EndOffset': 1083,
#     'Score': 0.9988101720809937,
#     'Text': 'ampicillin',
#     'Category': 'MEDICATION',
#     'Type': 'GENERIC_NAME',
#     'Traits': []},
#    {'Id': 37,
#     'BeginOffset': 1085,
#     'EndOffset': 1095,
#     'Score': 0.9996696710586548,
#     'Text': 'cefotaxime',
#     'Category': 'MEDICATION',
#     'Type': 'GENERIC_NAME',
#     'Traits': []},
#    {'Id': 38,
#     'BeginOffset': 1101,
#     'EndOffset': 1109,
#     'Score': 0.7591956853866577,
#     'Text': 'Rocephin',
#     'Category': 'MEDICATION',
#     'Type': 'BRAND_NAME',
#     'Traits': []},
#    {'Id': 41,
#     'BeginOffset': 1233,
#     'EndOffset': 1245,
#     'Score': 0.9928572177886963,
#     'Text': 'hypertension',
#     'Category': 'MEDICAL_CONDITION',
#     'Type': 'DX_NAME',
#     'Traits': [{'Name': 'DIAGNOSIS', 'Score': 0.9609277248382568}]},
#    {'Id': 42,
#     'BeginOffset': 1267,
#     'EndOffset': 1274,
#     'Score': 0.45536860823631287,
#     'Text': 'B strep',
#     'Category': 'MEDICAL_CONDITION',
#     'Type': 'DX_NAME',
#     'Traits': [{'Name': 'DIAGNOSIS', 'Score': 0.8012107610702515},
#      {'Name': 'NEGATION', 'Score': 0.8190817832946777}]},
#    {'Id': 43,
#     'BeginOffset': 1278,
#     'EndOffset': 1284,
#     'Score': 0.96087646484375,
#     'Text': 'herpes',
#     'Category': 'MEDICAL_CONDITION',
#     'Type': 'DX_NAME',
#     'Traits': [{'Name': 'DIAGNOSIS', 'Score': 0.8246643543243408},
#      {'Name': 'NEGATION', 'Score': 0.8591879606246948}]},
#    {'Id': 49,
#     'BeginOffset': 1322,
#     'EndOffset': 1335,
#     'Score': 0.598109781742096,
#     'Text': 'IMMUNIZATIONS',
#     'Category': 'TEST_TREATMENT_PROCEDURE',
#     'Type': 'TREATMENT_NAME',
#     'Traits': []},
#    {'Id': 44,
#     'BeginOffset': 1361,
#     'EndOffset': 1367,
#     'Score': 0.8354156017303467,
#     'Text': 'Thrush',
#     'Category': 'MEDICAL_CONDITION',
#     'Type': 'DX_NAME',
#     'Traits': [{'Name': 'DIAGNOSIS', 'Score': 0.8130917549133301}]},
#    {'Id': 39,
#     'BeginOffset': 1391,
#     'EndOffset': 1399,
#     'Score': 0.9955560564994812,
#     'Text': 'nystatin',
#     'Category': 'MEDICATION',
#     'Type': 'GENERIC_NAME',
#     'Traits': []},
#    {'Id': 40,
#     'BeginOffset': 1623,
#     'EndOffset': 1630,
#     'Score': 0.4219570457935333,
#     'Text': 'Enfamil',
#     'Category': 'MEDICATION',
#     'Type': 'GENERIC_NAME',
#     'Traits': []},
#    {'Id': 45,
#     'BeginOffset': 1652,
#     'EndOffset': 1669,
#     'Score': 0.9090202450752258,
#     'Text': 'decreased feeding',
#     'Category': 'MEDICAL_CONDITION',
#     'Type': 'DX_NAME',
#     'Traits': [{'Name': 'SYMPTOM', 'Score': 0.9040347337722778}]},
#    {'Id': 46,
#     'BeginOffset': 1679,
#     'EndOffset': 1687,
#     'Score': 0.996552586555481,
#     'Text': 'vomiting',
#     'Category': 'MEDICAL_CONDITION',
#     'Type': 'DX_NAME',
#     'Traits': [{'Name': 'SYMPTOM', 'Score': 0.8710067868232727}]},
#    {'Id': 47,
#     'BeginOffset': 1697,
#     'EndOffset': 1705,
#     'Score': 0.9981251358985901,
#     'Text': 'diarrhea',
#     'Category': 'MEDICAL_CONDITION',
#     'Type': 'DX_NAME',
#     'Traits': [{'Name': 'SYMPTOM', 'Score': 0.8357173204421997}]},
#    {'Id': 50,
#     'BeginOffset': 1761,
#     'EndOffset': 1781,
#     'Score': 0.32287266850471497,
#     'Text': 'PHYSICAL EXAMINATION',
#     'Category': 'TEST_TREATMENT_PROCEDURE',
#     'Type': 'TEST_NAME',
#     'Traits': []},
#    {'Id': 51,
#     'BeginOffset': 1784,
#     'EndOffset': 1803,
#     'Score': 0.9358009099960327,
#     'Text': 'VITAL SIGNS/GENERAL',
#     'Category': 'TEST_TREATMENT_PROCEDURE',
#     'Type': 'TEST_NAME',
#     'Traits': []},
#    {'Id': 52,
#     'BeginOffset': 1808,
#     'EndOffset': 1828,
#     'Score': 0.8467229604721069,
#     'Text': 'physical examination',
#     'Category': 'TEST_TREATMENT_PROCEDURE',
#     'Type': 'TEST_NAME',
#     'Traits': []},
#    {'Id': 111,
#     'BeginOffset': 1842,
#     'EndOffset': 1853,
#     'Score': 0.996519923210144,
#     'Text': 'temperature',
#     'Category': 'TEST_TREATMENT_PROCEDURE',
#     'Type': 'TEST_NAME',
#     'Traits': [],
#     'Attributes': [{'Type': 'TEST_VALUE',
#       'Score': 0.9999454021453857,
#       'RelationshipScore': 0.9999997615814209,
#       'RelationshipType': 'TEST_VALUE',
#       'Id': 112,
#       'BeginOffset': 1854,
#       'EndOffset': 1858,
#       'Text': '97.5',
#       'Category': 'TEST_TREATMENT_PROCEDURE',
#       'Traits': []}]},
#    {'Id': 113,
#     'BeginOffset': 1860,
#     'EndOffset': 1865,
#     'Score': 0.9984661340713501,
#     'Text': 'pulse',
#     'Category': 'TEST_TREATMENT_PROCEDURE',
#     'Type': 'TEST_NAME',
#     'Traits': [],
#     'Attributes': [{'Type': 'TEST_VALUE',
#       'Score': 0.9991187453269958,
#       'RelationshipScore': 0.9999847412109375,
#       'RelationshipType': 'TEST_VALUE',
#       'Id': 114,
#       'BeginOffset': 1866,
#       'EndOffset': 1869,
#       'Text': '140',
#       'Category': 'TEST_TREATMENT_PROCEDURE',
#       'Traits': []}]},
#    {'Id': 115,
#     'BeginOffset': 1871,
#     'EndOffset': 1883,
#     'Score': 0.9803449511528015,
#     'Text': 'respirations',
#     'Category': 'TEST_TREATMENT_PROCEDURE',
#     'Type': 'TEST_NAME',
#     'Traits': [],
#     'Attributes': [{'Type': 'TEST_VALUE',
#       'Score': 0.9928056597709656,
#       'RelationshipScore': 0.9999949932098389,
#       'RelationshipType': 'TEST_VALUE',
#       'Id': 116,
#       'BeginOffset': 1884,
#       'EndOffset': 1886,
#       'Text': '48',
#       'Category': 'TEST_TREATMENT_PROCEDURE',
#       'Traits': []}]},
#    {'Id': 74,
#     'BeginOffset': 1932,
#     'EndOffset': 1946,
#     'Score': 0.7143492102622986,
#     'Text': 'well-developed',
#     'Category': 'MEDICAL_CONDITION',
#     'Type': 'DX_NAME',
#     'Traits': [{'Name': 'SIGN', 'Score': 0.7923539876937866}]},
#    {'Id': 75,
#     'BeginOffset': 1955,
#     'EndOffset': 1970,
#     'Score': 0.6399262547492981,
#     'Text': 'age appropriate',
#     'Category': 'MEDICAL_CONDITION',
#     'Type': 'DX_NAME',
#     'Traits': [{'Name': 'SIGN', 'Score': 0.9551171064376831}]},
#    {'Id': 53,
#     'BeginOffset': 1973,
#     'EndOffset': 1978,
#     'Score': 0.992160975933075,
#     'Text': 'HEENT',
#     'Category': 'ANATOMY',
#     'Type': 'SYSTEM_ORGAN_SITE',
#     'Traits': []},
#    {'Id': 54,
#     'BeginOffset': 1980,
#     'EndOffset': 1984,
#     'Score': 0.9913967251777649,
#     'Text': 'Head',
#     'Category': 'ANATOMY',
#     'Type': 'SYSTEM_ORGAN_SITE',
#     'Traits': []},
#    {'Id': 76,
#     'BeginOffset': 1988,
#     'EndOffset': 1998,
#     'Score': 0.9917131662368774,
#     'Text': 'atraumatic',
#     'Category': 'MEDICAL_CONDITION',
#     'Type': 'DX_NAME',
#     'Traits': [{'Name': 'SIGN', 'Score': 0.9718956351280212}],
#     'Attributes': [{'Type': 'SYSTEM_ORGAN_SITE',
#       'Score': 0.992160975933075,
#       'RelationshipScore': 0.9989227652549744,
#       'RelationshipType': 'SYSTEM_ORGAN_SITE',
#       'Id': 53,
#       'BeginOffset': 1973,
#       'EndOffset': 1978,
#       'Text': 'HEENT',
#       'Category': 'ANATOMY',
#       'Traits': []},
#      {'Type': 'SYSTEM_ORGAN_SITE',
#       'Score': 0.9913967251777649,
#       'RelationshipScore': 0.9974744915962219,
#       'RelationshipType': 'SYSTEM_ORGAN_SITE',
#       'Id': 54,
#       'BeginOffset': 1980,
#       'EndOffset': 1984,
#       'Text': 'Head',
#       'Category': 'ANATOMY',
#       'Traits': []}]},
#    {'Id': 77,
#     'BeginOffset': 2003,
#     'EndOffset': 2016,
#     'Score': 0.9938769936561584,
#     'Text': 'normocephalic',
#     'Category': 'MEDICAL_CONDITION',
#     'Type': 'DX_NAME',
#     'Traits': [{'Name': 'SIGN', 'Score': 0.9616495966911316}],
#     'Attributes': [{'Type': 'SYSTEM_ORGAN_SITE',
#       'Score': 0.992160975933075,
#       'RelationshipScore': 0.9984014630317688,
#       'RelationshipType': 'SYSTEM_ORGAN_SITE',
#       'Id': 53,
#       'BeginOffset': 1973,
#       'EndOffset': 1978,
#       'Text': 'HEENT',
#       'Category': 'ANATOMY',
#       'Traits': []},
#      {'Type': 'SYSTEM_ORGAN_SITE',
#       'Score': 0.9913967251777649,
#       'RelationshipScore': 0.762794017791748,
#       'RelationshipType': 'SYSTEM_ORGAN_SITE',
#       'Id': 54,
#       'BeginOffset': 1980,
#       'EndOffset': 1984,
#       'Text': 'Head',
#       'Category': 'ANATOMY',
#       'Traits': []}]},
#    {'Id': 78,
#     'BeginOffset': 2024,
#     'EndOffset': 2028,
#     'Score': 0.8596504330635071,
#     'Text': 'soft',
#     'Category': 'MEDICAL_CONDITION',
#     'Type': 'DX_NAME',
#     'Traits': [{'Name': 'SIGN', 'Score': 0.9091911911964417}],
#     'Attributes': [{'Type': 'SYSTEM_ORGAN_SITE',
#       'Score': 0.992160975933075,
#       'RelationshipScore': 0.9986732006072998,
#       'RelationshipType': 'SYSTEM_ORGAN_SITE',
#       'Id': 53,
#       'BeginOffset': 1973,
#       'EndOffset': 1978,
#       'Text': 'HEENT',
#       'Category': 'ANATOMY',
#       'Traits': []},
#      {'Type': 'SYSTEM_ORGAN_SITE',
#       'Score': 0.9913967251777649,
#       'RelationshipScore': 0.8423815369606018,
#       'RelationshipType': 'SYSTEM_ORGAN_SITE',
#       'Id': 54,
#       'BeginOffset': 1980,
#       'EndOffset': 1984,
#       'Text': 'Head',
#       'Category': 'ANATOMY',
#       'Traits': []},
#      {'Type': 'DIRECTION',
#       'Score': 0.926945686340332,
#       'RelationshipScore': 0.8131041526794434,
#       'RelationshipType': 'DIRECTION',
#       'Id': 55,
#       'BeginOffset': 2038,
#       'EndOffset': 2046,
#       'Text': 'anterior',
#       'Category': 'ANATOMY',
#       'Traits': []},
#      {'Type': 'SYSTEM_ORGAN_SITE',
#       'Score': 0.6657260656356812,
#       'RelationshipScore': 0.615085244178772,
#       'RelationshipType': 'SYSTEM_ORGAN_SITE',
#       'Id': 56,
#       'BeginOffset': 2047,
#       'EndOffset': 2057,
#       'Text': 'fontanelle',
#       'Category': 'ANATOMY',
#       'Traits': []}]},
#    {'Id': 79,
#     'BeginOffset': 2033,
#     'EndOffset': 2057,
#     'Score': 0.4915967583656311,
#     'Text': 'flat anterior fontanelle',
#     'Category': 'MEDICAL_CONDITION',
#     'Type': 'DX_NAME',
#     'Traits': [{'Name': 'SIGN', 'Score': 0.8829711079597473}],
#     'Attributes': [{'Type': 'SYSTEM_ORGAN_SITE',
#       'Score': 0.992160975933075,
#       'RelationshipScore': 0.9999599456787109,
#       'RelationshipType': 'SYSTEM_ORGAN_SITE',
#       'Id': 53,
#       'BeginOffset': 1973,
#       'EndOffset': 1978,
#       'Text': 'HEENT',
#       'Category': 'ANATOMY',
#       'Traits': []},
#      {'Type': 'DIRECTION',
#       'Score': 0.926945686340332,
#       'RelationshipScore': 0.9455752968788147,
#       'RelationshipType': 'DIRECTION',
#       'Id': 55,
#       'BeginOffset': 2038,
#       'EndOffset': 2046,
#       'Text': 'anterior',
#       'Category': 'ANATOMY',
#       'Traits': []}]},
#    {'Id': 56,
#     'BeginOffset': 2047,
#     'EndOffset': 2057,
#     'Score': 0.6657260656356812,
#     'Text': 'fontanelle',
#     'Category': 'ANATOMY',
#     'Type': 'SYSTEM_ORGAN_SITE',
#     'Traits': []},
#    {'Id': 57,
#     'BeginOffset': 2059,
#     'EndOffset': 2065,
#     'Score': 0.9925347566604614,
#     'Text': 'Pupils',
#     'Category': 'ANATOMY',
#     'Type': 'SYSTEM_ORGAN_SITE',
#     'Traits': []},
#    {'Id': 80,
#     'BeginOffset': 2070,
#     'EndOffset': 2075,
#     'Score': 0.9934317469596863,
#     'Text': 'equal',
#     'Category': 'MEDICAL_CONDITION',
#     'Type': 'DX_NAME',
#     'Traits': [{'Name': 'SIGN', 'Score': 0.9592713117599487}],
#     'Attributes': [{'Type': 'SYSTEM_ORGAN_SITE',
#       'Score': 0.992160975933075,
#       'RelationshipScore': 0.9995237588882446,
#       'RelationshipType': 'SYSTEM_ORGAN_SITE',
#       'Id': 53,
#       'BeginOffset': 1973,
#       'EndOffset': 1978,
#       'Text': 'HEENT',
#       'Category': 'ANATOMY',
#       'Traits': []},
#      {'Type': 'DIRECTION',
#       'Score': 0.926945686340332,
#       'RelationshipScore': 0.9818234443664551,
#       'RelationshipType': 'DIRECTION',
#       'Id': 55,
#       'BeginOffset': 2038,
#       'EndOffset': 2046,
#       'Text': 'anterior',
#       'Category': 'ANATOMY',
#       'Traits': []},
#      {'Type': 'SYSTEM_ORGAN_SITE',
#       'Score': 0.6657260656356812,
#       'RelationshipScore': 0.5904496312141418,
#       'RelationshipType': 'SYSTEM_ORGAN_SITE',
#       'Id': 56,
#       'BeginOffset': 2047,
#       'EndOffset': 2057,
#       'Text': 'fontanelle',
#       'Category': 'ANATOMY',
#       'Traits': []},
#      {'Type': 'SYSTEM_ORGAN_SITE',
#       'Score': 0.9925347566604614,
#       'RelationshipScore': 0.9993065595626831,
#       'RelationshipType': 'SYSTEM_ORGAN_SITE',
#       'Id': 57,
#       'BeginOffset': 2059,
#       'EndOffset': 2065,
#       'Text': 'Pupils',
#       'Category': 'ANATOMY',
#       'Traits': []}]},
#    {'Id': 81,
#     'BeginOffset': 2077,
#     'EndOffset': 2082,
#     'Score': 0.9967201352119446,
#     'Text': 'round',
#     'Category': 'MEDICAL_CONDITION',
#     'Type': 'DX_NAME',
#     'Traits': [{'Name': 'SIGN', 'Score': 0.9717308878898621}],
#     'Attributes': [{'Type': 'SYSTEM_ORGAN_SITE',
#       'Score': 0.992160975933075,
#       'RelationshipScore': 0.999858021736145,
#       'RelationshipType': 'SYSTEM_ORGAN_SITE',
#       'Id': 53,
#       'BeginOffset': 1973,
#       'EndOffset': 1978,
#       'Text': 'HEENT',
#       'Category': 'ANATOMY',
#       'Traits': []},
#      {'Type': 'DIRECTION',
#       'Score': 0.926945686340332,
#       'RelationshipScore': 0.9845486879348755,
#       'RelationshipType': 'DIRECTION',
#       'Id': 55,
#       'BeginOffset': 2038,
#       'EndOffset': 2046,
#       'Text': 'anterior',
#       'Category': 'ANATOMY',
#       'Traits': []},
#      {'Type': 'SYSTEM_ORGAN_SITE',
#       'Score': 0.9925347566604614,
#       'RelationshipScore': 0.999152660369873,
#       'RelationshipType': 'SYSTEM_ORGAN_SITE',
#       'Id': 57,
#       'BeginOffset': 2059,
#       'EndOffset': 2065,
#       'Text': 'Pupils',
#       'Category': 'ANATOMY',
#       'Traits': []}]},
#    {'Id': 82,
#     'BeginOffset': 2088,
#     'EndOffset': 2105,
#     'Score': 0.9844431281089783,
#     'Text': 'reactive to light',
#     'Category': 'MEDICAL_CONDITION',
#     'Type': 'DX_NAME',
#     'Traits': [{'Name': 'SIGN', 'Score': 0.8502365350723267}],
#     'Attributes': [{'Type': 'SYSTEM_ORGAN_SITE',
#       'Score': 0.992160975933075,
#       'RelationshipScore': 0.9997255206108093,
#       'RelationshipType': 'SYSTEM_ORGAN_SITE',
#       'Id': 53,
#       'BeginOffset': 1973,
#       'EndOffset': 1978,
#       'Text': 'HEENT',
#       'Category': 'ANATOMY',
#       'Traits': []},
#      {'Type': 'DIRECTION',
#       'Score': 0.926945686340332,
#       'RelationshipScore': 0.9879937171936035,
#       'RelationshipType': 'DIRECTION',
#       'Id': 55,
#       'BeginOffset': 2038,
#       'EndOffset': 2046,
#       'Text': 'anterior',
#       'Category': 'ANATOMY',
#       'Traits': []},
#      {'Type': 'SYSTEM_ORGAN_SITE',
#       'Score': 0.9925347566604614,
#       'RelationshipScore': 0.9976940751075745,
#       'RelationshipType': 'SYSTEM_ORGAN_SITE',
#       'Id': 57,
#       'BeginOffset': 2059,
#       'EndOffset': 2065,
#       'Text': 'Pupils',
#       'Category': 'ANATOMY',
#       'Traits': []}]},
#    {'Id': 83,
#     'BeginOffset': 2107,
#     'EndOffset': 2124,
#     'Score': 0.6882385611534119,
#     'Text': 'Grossly conjugate',
#     'Category': 'MEDICAL_CONDITION',
#     'Type': 'DX_NAME',
#     'Traits': [{'Name': 'SIGN', 'Score': 0.9543132185935974}],
#     'Attributes': [{'Type': 'SYSTEM_ORGAN_SITE',
#       'Score': 0.992160975933075,
#       'RelationshipScore': 0.9995778203010559,
#       'RelationshipType': 'SYSTEM_ORGAN_SITE',
#       'Id': 53,
#       'BeginOffset': 1973,
#       'EndOffset': 1978,
#       'Text': 'HEENT',
#       'Category': 'ANATOMY',
#       'Traits': []},
#      {'Type': 'SYSTEM_ORGAN_SITE',
#       'Score': 0.9925347566604614,
#       'RelationshipScore': 0.9099558591842651,
#       'RelationshipType': 'SYSTEM_ORGAN_SITE',
#       'Id': 57,
#       'BeginOffset': 2059,
#       'EndOffset': 2065,
#       'Text': 'Pupils',
#       'Category': 'ANATOMY',
#       'Traits': []}]},
#    {'Id': 84,
#     'BeginOffset': 2136,
#     'EndOffset': 2146,
#     'Score': 0.7073736786842346,
#     'Text': 'red reflex',
#     'Category': 'MEDICAL_CONDITION',
#     'Type': 'DX_NAME',
#     'Traits': [{'Name': 'SIGN', 'Score': 0.8856950998306274}],
#     'Attributes': [{'Type': 'DIRECTION',
#       'Score': 0.9755227565765381,
#       'RelationshipScore': 0.9998276233673096,
#       'RelationshipType': 'DIRECTION',
#       'Id': 58,
#       'BeginOffset': 2126,
#       'EndOffset': 2135,
#       'Text': 'Bilateral',
#       'Category': 'ANATOMY',
#       'Traits': []},
#      {'Type': 'DIRECTION',
#       'Score': 0.9957470297813416,
#       'RelationshipScore': 0.9999244213104248,
#       'RelationshipType': 'DIRECTION',
#       'Id': 59,
#       'BeginOffset': 2159,
#       'EndOffset': 2170,
#       'Text': 'bilaterally',
#       'Category': 'ANATOMY',
#       'Traits': []}]},
#    {'Id': 85,
#     'BeginOffset': 2172,
#     'EndOffset': 2203,
#     'Score': 0.8880147337913513,
#     'Text': 'Clear TMs, nose, and oropharynx',
#     'Category': 'MEDICAL_CONDITION',
#     'Type': 'DX_NAME',
#     'Traits': [{'Name': 'SIGN', 'Score': 0.64443439245224}]},
#    {'Id': 60,
#     'BeginOffset': 2178,
#     'EndOffset': 2181,
#     'Score': 0.9767493009567261,
#     'Text': 'TMs',
#     'Category': 'ANATOMY',
#     'Type': 'SYSTEM_ORGAN_SITE',
#     'Traits': []},
#    {'Id': 61,
#     'BeginOffset': 2183,
#     'EndOffset': 2187,
#     'Score': 0.9953895807266235,
#     'Text': 'nose',
#     'Category': 'ANATOMY',
#     'Type': 'SYSTEM_ORGAN_SITE',
#     'Traits': []},
#    {'Id': 62,
#     'BeginOffset': 2193,
#     'EndOffset': 2203,
#     'Score': 0.9953472018241882,
#     'Text': 'oropharynx',
#     'Category': 'ANATOMY',
#     'Type': 'SYSTEM_ORGAN_SITE',
#     'Traits': []},
#    {'Id': 86,
#     'BeginOffset': 2233,
#     'EndOffset': 2239,
#     'Score': 0.990372896194458,
#     'Text': 'thrush',
#     'Category': 'MEDICAL_CONDITION',
#     'Type': 'DX_NAME',
#     'Traits': [{'Name': 'SIGN', 'Score': 0.9296254515647888}]},
#    {'Id': 87,
#     'BeginOffset': 2244,
#     'EndOffset': 2257,
#     'Score': 0.7072054147720337,
#     'Text': 'white patches',
#     'Category': 'MEDICAL_CONDITION',
#     'Type': 'DX_NAME',
#     'Traits': [{'Name': 'SIGN', 'Score': 0.8768698573112488}],
#     'Attributes': [{'Type': 'SYSTEM_ORGAN_SITE',
#       'Score': 0.9845282435417175,
#       'RelationshipScore': 0.999994158744812,
#       'RelationshipType': 'SYSTEM_ORGAN_SITE',
#       'Id': 63,
#       'BeginOffset': 2265,
#       'EndOffset': 2271,
#       'Text': 'tongue',
#       'Category': 'ANATOMY',
#       'Traits': []}]},
#    {'Id': 63,
#     'BeginOffset': 2265,
#     'EndOffset': 2271,
#     'Score': 0.9845282435417175,
#     'Text': 'tongue',
#     'Category': 'ANATOMY',
#     'Type': 'SYSTEM_ORGAN_SITE',
#     'Traits': []},
#    {'Id': 64,
#     'BeginOffset': 2274,
#     'EndOffset': 2278,
#     'Score': 0.9985252022743225,
#     'Text': 'NECK',
#     'Category': 'ANATOMY',
#     'Type': 'SYSTEM_ORGAN_SITE',
#     'Traits': []},
#    {'Id': 88,
#     'BeginOffset': 2280,
#     'EndOffset': 2286,
#     'Score': 0.9913076758384705,
#     'Text': 'Supple',
#     'Category': 'MEDICAL_CONDITION',
#     'Type': 'DX_NAME',
#     'Traits': [{'Name': 'SIGN', 'Score': 0.963746964931488}],
#     'Attributes': [{'Type': 'SYSTEM_ORGAN_SITE',
#       'Score': 0.9985252022743225,
#       'RelationshipScore': 0.7593419551849365,
#       'RelationshipType': 'SYSTEM_ORGAN_SITE',
#       'Id': 64,
#       'BeginOffset': 2274,
#       'EndOffset': 2278,
#       'Text': 'NECK',
#       'Category': 'ANATOMY',
#       'Traits': []}]},
#    {'Id': 89,
#     'BeginOffset': 2288,
#     'EndOffset': 2292,
#     'Score': 0.6340267658233643,
#     'Text': 'full',
#     'Category': 'MEDICAL_CONDITION',
#     'Type': 'DX_NAME',
#     'Traits': [{'Name': 'SIGN', 'Score': 0.5468843579292297}],
#     'Attributes': [{'Type': 'SYSTEM_ORGAN_SITE',
#       'Score': 0.9985252022743225,
#       'RelationshipScore': 0.8390793800354004,
#       'RelationshipType': 'SYSTEM_ORGAN_SITE',
#       'Id': 64,
#       'BeginOffset': 2274,
#       'EndOffset': 2278,
#       'Text': 'NECK',
#       'Category': 'ANATOMY',
#       'Traits': []}]},
#    {'Id': 90,
#     'BeginOffset': 2294,
#     'EndOffset': 2302,
#     'Score': 0.8398376703262329,
#     'Text': 'painless',
#     'Category': 'MEDICAL_CONDITION',
#     'Type': 'DX_NAME',
#     'Traits': [{'Name': 'SIGN', 'Score': 0.7659049034118652}],
#     'Attributes': [{'Type': 'SYSTEM_ORGAN_SITE',
#       'Score': 0.9985252022743225,
#       'RelationshipScore': 0.788544237613678,
#       'RelationshipType': 'SYSTEM_ORGAN_SITE',
#       'Id': 64,
#       'BeginOffset': 2274,
#       'EndOffset': 2278,
#       'Text': 'NECK',
#       'Category': 'ANATOMY',
#       'Traits': []}]},
#    {'Id': 91,
#     'BeginOffset': 2307,
#     'EndOffset': 2316,
#     'Score': 0.9914230704307556,
#     'Text': 'nontender',
#     'Category': 'MEDICAL_CONDITION',
#     'Type': 'DX_NAME',
#     'Traits': [{'Name': 'SIGN', 'Score': 0.9455214738845825}],
#     'Attributes': [{'Type': 'SYSTEM_ORGAN_SITE',
#       'Score': 0.9985252022743225,
#       'RelationshipScore': 0.6202957630157471,
#       'RelationshipType': 'SYSTEM_ORGAN_SITE',
#       'Id': 64,
#       'BeginOffset': 2274,
#       'EndOffset': 2278,
#       'Text': 'NECK',
#       'Category': 'ANATOMY',
#       'Traits': []}]},
#    {'Id': 92,
#     'BeginOffset': 2317,
#     'EndOffset': 2332,
#     'Score': 0.9291130900382996,
#     'Text': 'range of motion',
#     'Category': 'MEDICAL_CONDITION',
#     'Type': 'DX_NAME',
#     'Traits': [{'Name': 'SIGN', 'Score': 0.8856569528579712}],
#     'Attributes': [{'Type': 'SYSTEM_ORGAN_SITE',
#       'Score': 0.9985252022743225,
#       'RelationshipScore': 0.8536641001701355,
#       'RelationshipType': 'SYSTEM_ORGAN_SITE',
#       'Id': 64,
#       'BeginOffset': 2274,
#       'EndOffset': 2278,
#       'Text': 'NECK',
#       'Category': 'ANATOMY',
#       'Traits': []}]},
#    {'Id': 65,
#     'BeginOffset': 2334,
#     'EndOffset': 2339,
#     'Score': 0.9570780396461487,
#     'Text': 'CHEST',
#     'Category': 'ANATOMY',
#     'Type': 'SYSTEM_ORGAN_SITE',
#     'Traits': []},
#    {'Id': 93,
#     'BeginOffset': 2334,
#     'EndOffset': 2346,
#     'Score': 0.5406209826469421,
#     'Text': 'CHEST motion',
#     'Category': 'MEDICAL_CONDITION',
#     'Type': 'DX_NAME',
#     'Traits': [{'Name': 'SIGN', 'Score': 0.8416481614112854}],
#     'Attributes': [{'Type': 'SYSTEM_ORGAN_SITE',
#       'Score': 0.9985252022743225,
#       'RelationshipScore': 0.8778603672981262,
#       'RelationshipType': 'SYSTEM_ORGAN_SITE',
#       'Id': 64,
#       'BeginOffset': 2274,
#       'EndOffset': 2278,
#       'Text': 'NECK',
#       'Category': 'ANATOMY',
#       'Traits': []}]},
#    {'Id': 66,
#     'BeginOffset': 2350,
#     'EndOffset': 2355,
#     'Score': 0.9985888600349426,
#     'Text': 'CHEST',
#     'Category': 'ANATOMY',
#     'Type': 'SYSTEM_ORGAN_SITE',
#     'Traits': []},
#    {'Id': 94,
#     'BeginOffset': 2357,
#     'EndOffset': 2378,
#     'Score': 0.9856179356575012,
#     'Text': 'Clear to auscultation',
#     'Category': 'MEDICAL_CONDITION',
#     'Type': 'DX_NAME',
#     'Traits': [{'Name': 'SIGN', 'Score': 0.897045910358429}],
#     'Attributes': [{'Type': 'SYSTEM_ORGAN_SITE',
#       'Score': 0.9985252022743225,
#       'RelationshipScore': 0.627667248249054,
#       'RelationshipType': 'SYSTEM_ORGAN_SITE',
#       'Id': 64,
#       'BeginOffset': 2274,
#       'EndOffset': 2278,
#       'Text': 'NECK',
#       'Category': 'ANATOMY',
#       'Traits': []},
#      {'Type': 'SYSTEM_ORGAN_SITE',
#       'Score': 0.9985888600349426,
#       'RelationshipScore': 0.6301782727241516,
#       'RelationshipType': 'SYSTEM_ORGAN_SITE',
#       'Id': 66,
#       'BeginOffset': 2350,
#       'EndOffset': 2355,
#       'Text': 'CHEST',
#       'Category': 'ANATOMY',
#       'Traits': []}]},
#    {'Id': 95,
#     'BeginOffset': 2380,
#     'EndOffset': 2385,
#     'Score': 0.9536371231079102,
#     'Text': 'equal',
#     'Category': 'MEDICAL_CONDITION',
#     'Type': 'DX_NAME',
#     'Traits': [{'Name': 'SIGN', 'Score': 0.9194133877754211}],
#     'Attributes': [{'Type': 'SYSTEM_ORGAN_SITE',
#       'Score': 0.9985888600349426,
#       'RelationshipScore': 0.6889069676399231,
#       'RelationshipType': 'SYSTEM_ORGAN_SITE',
#       'Id': 66,
#       'BeginOffset': 2350,
#       'EndOffset': 2355,
#       'Text': 'CHEST',
#       'Category': 'ANATOMY',
#       'Traits': []}]},
#    {'Id': 96,
#     'BeginOffset': 2391,
#     'EndOffset': 2397,
#     'Score': 0.8563752770423889,
#     'Text': 'stable',
#     'Category': 'MEDICAL_CONDITION',
#     'Type': 'DX_NAME',
#     'Traits': [{'Name': 'SIGN', 'Score': 0.8783522844314575}],
#     'Attributes': [{'Type': 'SYSTEM_ORGAN_SITE',
#       'Score': 0.9985888600349426,
#       'RelationshipScore': 0.5042008757591248,
#       'RelationshipType': 'SYSTEM_ORGAN_SITE',
#       'Id': 66,
#       'BeginOffset': 2350,
#       'EndOffset': 2355,
#       'Text': 'CHEST',
#       'Category': 'ANATOMY',
#       'Traits': []}]},
#    {'Id': 67,
#     'BeginOffset': 2400,
#     'EndOffset': 2405,
#     'Score': 0.9978100657463074,
#     'Text': 'HEART',
#     'Category': 'ANATOMY',
#     'Type': 'SYSTEM_ORGAN_SITE',
#     'Traits': []},
#    {'Id': 97,
#     'BeginOffset': 2407,
#     'EndOffset': 2414,
#     'Score': 0.731455385684967,
#     'Text': 'Regular',
#     'Category': 'MEDICAL_CONDITION',
#     'Type': 'DX_NAME',
#     'Traits': [{'Name': 'SIGN', 'Score': 0.8095032572746277}],
#     'Attributes': [{'Type': 'SYSTEM_ORGAN_SITE',
#       'Score': 0.9978100657463074,
#       'RelationshipScore': 0.853549599647522,
#       'RelationshipType': 'SYSTEM_ORGAN_SITE',
#       'Id': 67,
#       'BeginOffset': 2400,
#       'EndOffset': 2405,
#       'Text': 'HEART',
#       'Category': 'ANATOMY',
#       'Traits': []}]},
#    {'Id': 98,
#     'BeginOffset': 2423,
#     'EndOffset': 2427,
#     'Score': 0.997700035572052,
#     'Text': 'rubs',
#     'Category': 'MEDICAL_CONDITION',
#     'Type': 'DX_NAME',
#     'Traits': [{'Name': 'SIGN', 'Score': 0.9844021797180176},
#      {'Name': 'NEGATION', 'Score': 0.9906318187713623}],
#     'Attributes': [{'Type': 'SYSTEM_ORGAN_SITE',
#       'Score': 0.9978100657463074,
#       'RelationshipScore': 0.6781035661697388,
#       'RelationshipType': 'SYSTEM_ORGAN_SITE',
#       'Id': 67,
#       'BeginOffset': 2400,
#       'EndOffset': 2405,
#       'Text': 'HEART',
#       'Category': 'ANATOMY',
#       'Traits': []}]},
#    {'Id': 99,
#     'BeginOffset': 2431,
#     'EndOffset': 2438,
#     'Score': 0.9991104006767273,
#     'Text': 'murmurs',
#     'Category': 'MEDICAL_CONDITION',
#     'Type': 'DX_NAME',
#     'Traits': [{'Name': 'SIGN', 'Score': 0.9805101156234741},
#      {'Name': 'NEGATION', 'Score': 0.9731805324554443}],
#     'Attributes': [{'Type': 'SYSTEM_ORGAN_SITE',
#       'Score': 0.9978100657463074,
#       'RelationshipScore': 0.8039031624794006,
#       'RelationshipType': 'SYSTEM_ORGAN_SITE',
#       'Id': 67,
#       'BeginOffset': 2400,
#       'EndOffset': 2405,
#       'Text': 'HEART',
#       'Category': 'ANATOMY',
#       'Traits': []}]},
#    {'Id': 100,
#     'BeginOffset': 2444,
#     'EndOffset': 2458,
#     'Score': 0.9566333889961243,
#     'Text': 'femoral pulses',
#     'Category': 'MEDICAL_CONDITION',
#     'Type': 'DX_NAME',
#     'Traits': [{'Name': 'SIGN', 'Score': 0.6190908551216125}],
#     'Attributes': [{'Type': 'SYSTEM_ORGAN_SITE',
#       'Score': 0.9978100657463074,
#       'RelationshipScore': 0.8621281981468201,
#       'RelationshipType': 'SYSTEM_ORGAN_SITE',
#       'Id': 67,
#       'BeginOffset': 2400,
#       'EndOffset': 2405,
#       'Text': 'HEART',
#       'Category': 'ANATOMY',
#       'Traits': []},
#      {'Type': 'DIRECTION',
#       'Score': 0.9936468601226807,
#       'RelationshipScore': 0.9999576807022095,
#       'RelationshipType': 'DIRECTION',
#       'Id': 68,
#       'BeginOffset': 2475,
#       'EndOffset': 2486,
#       'Text': 'bilaterally',
#       'Category': 'ANATOMY',
#       'Traits': []}]},
#    {'Id': 69,
#     'BeginOffset': 2488,
#     'EndOffset': 2495,
#     'Score': 0.9989025592803955,
#     'Text': 'ABDOMEN',
#     'Category': 'ANATOMY',
#     'Type': 'SYSTEM_ORGAN_SITE',
#     'Traits': []},
#    {'Id': 101,
#     'BeginOffset': 2497,
#     'EndOffset': 2501,
#     'Score': 0.9899709820747375,
#     'Text': 'Soft',
#     'Category': 'MEDICAL_CONDITION',
#     'Type': 'DX_NAME',
#     'Traits': [{'Name': 'SIGN', 'Score': 0.9485121369361877}],
#     'Attributes': [{'Type': 'SYSTEM_ORGAN_SITE',
#       'Score': 0.9989025592803955,
#       'RelationshipScore': 0.9216476082801819,
#       'RelationshipType': 'SYSTEM_ORGAN_SITE',
#       'Id': 69,
#       'BeginOffset': 2488,
#       'EndOffset': 2495,
#       'Text': 'ABDOMEN',
#       'Category': 'ANATOMY',
#       'Traits': []}]},
#    {'Id': 102,
#     'BeginOffset': 2506,
#     'EndOffset': 2515,
#     'Score': 0.9974309802055359,
#     'Text': 'nontender',
#     'Category': 'MEDICAL_CONDITION',
#     'Type': 'DX_NAME',
#     'Traits': [{'Name': 'SIGN', 'Score': 0.9653870463371277}],
#     'Attributes': [{'Type': 'SYSTEM_ORGAN_SITE',
#       'Score': 0.9989025592803955,
#       'RelationshipScore': 0.9293644428253174,
#       'RelationshipType': 'SYSTEM_ORGAN_SITE',
#       'Id': 69,
#       'BeginOffset': 2488,
#       'EndOffset': 2495,
#       'Text': 'ABDOMEN',
#       'Category': 'ANATOMY',
#       'Traits': []}]},
#    {'Id': 103,
#     'BeginOffset': 2520,
#     'EndOffset': 2538,
#     'Score': 0.9971441626548767,
#     'Text': 'hepatosplenomegaly',
#     'Category': 'MEDICAL_CONDITION',
#     'Type': 'DX_NAME',
#     'Traits': [{'Name': 'SIGN', 'Score': 0.955848217010498},
#      {'Name': 'NEGATION', 'Score': 0.8577616810798645}],
#     'Attributes': [{'Type': 'SYSTEM_ORGAN_SITE',
#       'Score': 0.9989025592803955,
#       'RelationshipScore': 0.9778615832328796,
#       'RelationshipType': 'SYSTEM_ORGAN_SITE',
#       'Id': 69,
#       'BeginOffset': 2488,
#       'EndOffset': 2495,
#       'Text': 'ABDOMEN',
#       'Category': 'ANATOMY',
#       'Traits': []}]},
#    {'Id': 104,
#     'BeginOffset': 2542,
#     'EndOffset': 2545,
#     'Score': 0.9839668869972229,
#     'Text': 'Ses',
#     'Category': 'MEDICAL_CONDITION',
#     'Type': 'DX_NAME',
#     'Traits': [{'Name': 'SIGN', 'Score': 0.9469105005264282},
#      {'Name': 'NEGATION', 'Score': 0.9359081983566284}],
#     'Attributes': [{'Type': 'SYSTEM_ORGAN_SITE',
#       'Score': 0.9989025592803955,
#       'RelationshipScore': 0.9802103638648987,
#       'RelationshipType': 'SYSTEM_ORGAN_SITE',
#       'Id': 69,
#       'BeginOffset': 2488,
#       'EndOffset': 2495,
#       'Text': 'ABDOMEN',
#       'Category': 'ANATOMY',
#       'Traits': []}]},
#    {'Id': 70,
#     'BeginOffset': 2547,
#     'EndOffset': 2556,
#     'Score': 0.8601658940315247,
#     'Text': 'GENITALIA',
#     'Category': 'ANATOMY',
#     'Type': 'SYSTEM_ORGAN_SITE',
#     'Traits': []},
#    {'Id': 105,
#     'BeginOffset': 2547,
#     'EndOffset': 2596,
#     'Score': 0.46001747250556946,
#     'Text': 'GENITALIA Female genitalia is present on a visual',
#     'Category': 'MEDICAL_CONDITION',
#     'Type': 'DX_NAME',
#     'Traits': [{'Name': 'SIGN', 'Score': 0.7331660985946655}],
#     'Attributes': [{'Type': 'SYSTEM_ORGAN_SITE',
#       'Score': 0.9989025592803955,
#       'RelationshipScore': 0.7348624467849731,
#       'RelationshipType': 'SYSTEM_ORGAN_SITE',
#       'Id': 69,
#       'BeginOffset': 2488,
#       'EndOffset': 2495,
#       'Text': 'ABDOMEN',
#       'Category': 'ANATOMY',
#       'Traits': []}]},
#    {'Id': 71,
#     'BeginOffset': 2564,
#     'EndOffset': 2573,
#     'Score': 0.888046383857727,
#     'Text': 'genitalia',
#     'Category': 'ANATOMY',
#     'Type': 'SYSTEM_ORGAN_SITE',
#     'Traits': []},
#    {'Id': 106,
#     'BeginOffset': 2610,
#     'EndOffset': 2612,
#     'Score': 0.39979803562164307,
#     'Text': 'SK',
#     'Category': 'MEDICAL_CONDITION',
#     'Type': 'DX_NAME',
#     'Traits': [],
#     'Attributes': [{'Type': 'SYSTEM_ORGAN_SITE',
#       'Score': 0.9989025592803955,
#       'RelationshipScore': 0.6751290559768677,
#       'RelationshipType': 'SYSTEM_ORGAN_SITE',
#       'Id': 69,
#       'BeginOffset': 2488,
#       'EndOffset': 2495,
#       'Text': 'ABDOMEN',
#       'Category': 'ANATOMY',
#       'Traits': []}]},
#    {'Id': 107,
#     'BeginOffset': 2628,
#     'EndOffset': 2636,
#     'Score': 0.9989847540855408,
#     'Text': 'bruising',
#     'Category': 'MEDICAL_CONDITION',
#     'Type': 'DX_NAME',
#     'Traits': [{'Name': 'SIGN', 'Score': 0.9806177020072937},
#      {'Name': 'NEGATION', 'Score': 0.9879744052886963}]},
#    {'Id': 108,
#     'BeginOffset': 2638,
#     'EndOffset': 2645,
#     'Score': 0.9984933137893677,
#     'Text': 'lesions',
#     'Category': 'MEDICAL_CONDITION',
#     'Type': 'DX_NAME',
#     'Traits': [{'Name': 'SIGN', 'Score': 0.9741829037666321},
#      {'Name': 'NEGATION', 'Score': 0.9860348701477051}]},
#    {'Id': 109,
#     'BeginOffset': 2650,
#     'EndOffset': 2654,
#     'Score': 0.9988064765930176,
#     'Text': 'rash',
#     'Category': 'MEDICAL_CONDITION',
#     'Type': 'DX_NAME',
#     'Traits': [{'Name': 'SIGN', 'Score': 0.9717795252799988},
#      {'Name': 'NEGATION', 'Score': 0.993093729019165}]},
#    {'Id': 72,
#     'BeginOffset': 2659,
#     'EndOffset': 2670,
#     'Score': 0.996705949306488,
#     'Text': 'EXTREMITIES',
#     'Category': 'ANATOMY',
#     'Type': 'SYSTEM_ORGAN_SITE',
#     'Traits': []},
#    {'Id': 110,
#     'BeginOffset': 2672,
#     'EndOffset': 2693,
#     'Score': 0.7234720587730408,
#     'Text': 'Moves all extremities',
#     'Category': 'MEDICAL_CONDITION',
#     'Type': 'DX_NAME',
#     'Traits': [{'Name': 'SIGN', 'Score': 0.8434754610061646}],
#     'Attributes': [{'Type': 'SYSTEM_ORGAN_SITE',
#       'Score': 0.996705949306488,
#       'RelationshipScore': 0.9988644123077393,
#       'RelationshipType': 'SYSTEM_ORGAN_SITE',
#       'Id': 72,
#       'BeginOffset': 2659,
#       'EndOffset': 2670,
#       'Text': 'EXTREMITIES',
#       'Category': 'ANATOMY',
#       'Traits': []}]},
#    {'Id': 73,
#     'BeginOffset': 2678,
#     'EndOffset': 2693,
#     'Score': 0.9084136486053467,
#     'Text': 'all extremities',
#     'Category': 'ANATOMY',
#     'Type': 'SYSTEM_ORGAN_SITE',
#     'Traits': []},
#    {'Id': 119,
#     'BeginOffset': 2699,
#     'EndOffset': 2708,
#     'Score': 0.9492974877357483,
#     'Text': 'nontender',
#     'Category': 'MEDICAL_CONDITION',
#     'Type': 'DX_NAME',
#     'Traits': [{'Name': 'SIGN', 'Score': 0.8983744382858276}]},
#    {'Id': 120,
#     'BeginOffset': 2713,
#     'EndOffset': 2722,
#     'Score': 0.9953516721725464,
#     'Text': 'deformity',
#     'Category': 'MEDICAL_CONDITION',
#     'Type': 'DX_NAME',
#     'Traits': [{'Name': 'SIGN', 'Score': 0.9535233378410339},
#      {'Name': 'NEGATION', 'Score': 0.9691545367240906}]},
#    {'Id': 117,
#     'BeginOffset': 2724,
#     'EndOffset': 2743,
#     'Score': 0.2364339977502823,
#     'Text': 'NEUROLOGICALLY Eyes',
#     'Category': 'ANATOMY',
#     'Type': 'SYSTEM_ORGAN_SITE',
#     'Traits': []},
#    {'Id': 121,
#     'BeginOffset': 2724,
#     'EndOffset': 2748,
#     'Score': 0.8506649732589722,
#     'Text': 'NEUROLOGICALLY Eyes open',
#     'Category': 'MEDICAL_CONDITION',
#     'Type': 'DX_NAME',
#     'Traits': [{'Name': 'SIGN', 'Score': 0.8598801493644714}]},
#    {'Id': 122,
#     'BeginOffset': 2750,
#     'EndOffset': 2771,
#     'Score': 0.7678545713424683,
#     'Text': 'moves all extremities',
#     'Category': 'MEDICAL_CONDITION',
#     'Type': 'DX_NAME',
#     'Traits': [{'Name': 'SIGN', 'Score': 0.7109724283218384}]},
#    {'Id': 118,
#     'BeginOffset': 2756,
#     'EndOffset': 2771,
#     'Score': 0.9585952758789062,
#     'Text': 'all extremities',
#     'Category': 'ANATOMY',
#     'Type': 'SYSTEM_ORGAN_SITE',
#     'Traits': []},
#    {'Id': 123,
#     'BeginOffset': 2773,
#     'EndOffset': 2784,
#     'Score': 0.6267024278640747,
#     'Text': 'grossly age',
#     'Category': 'MEDICAL_CONDITION',
#     'Type': 'DX_NAME',
#     'Traits': [{'Name': 'SIGN', 'Score': 0.8335615396499634}]},
#    {'Id': 124,
#     'BeginOffset': 2785,
#     'EndOffset': 2796,
#     'Score': 0.6155011057853699,
#     'Text': 'appropriate',
#     'Category': 'MEDICAL_CONDITION',
#     'Type': 'DX_NAME',
#     'Traits': [{'Name': 'SIGN', 'Score': 0.6856662034988403}]}],
#   'UnmappedAttributes': [{'Type': 'ANATOMY',
#     'Attribute': {'Type': 'DIRECTION',
#      'Score': 0.926945686340332,
#      'Id': 55,
#      'BeginOffset': 2038,
#      'EndOffset': 2046,
#      'Text': 'anterior',
#      'Category': 'ANATOMY',
#      'Traits': []}},
#    {'Type': 'ANATOMY',
#     'Attribute': {'Type': 'DIRECTION',
#      'Score': 0.9755227565765381,
#      'Id': 58,
#      'BeginOffset': 2126,
#      'EndOffset': 2135,
#      'Text': 'Bilateral',
#      'Category': 'ANATOMY',
#      'Traits': []}},
#    {'Type': 'ANATOMY',
#     'Attribute': {'Type': 'DIRECTION',
#      'Score': 0.9957470297813416,
#      'Id': 59,
#      'BeginOffset': 2159,
#      'EndOffset': 2170,
#      'Text': 'bilaterally',
#      'Category': 'ANATOMY',
#      'Traits': []}},
#    {'Type': 'ANATOMY',
#     'Attribute': {'Type': 'DIRECTION',
#      'Score': 0.9936468601226807,
#      'Id': 68,
#      'BeginOffset': 2475,
#      'EndOffset': 2486,
#      'Text': 'bilaterally',
#      'Category': 'ANATOMY',
#      'Traits': []}}],
#   'ModelVersion': '1.0.0',
#   'ResponseMetadata': {'RequestId': '6905699e-da5a-42a7-98c3-8185580abdab',
#    'HTTPStatusCode': 200,
#    'HTTPHeaders': {'x-amzn-requestid': '6905699e-da5a-42a7-98c3-8185580abdab',
#     'content-type': 'application/x-amz-json-1.1',
#     'content-length': '34286',
#     'date': 'Sun, 06 Sep 2020 16:32:15 GMT'},
#    'RetryAttempts': 0}},
#  {'Entities': [{'Id': 6,
#     'BeginOffset': 0,
#     'EndOffset': 27,
#     'Score': 0.4997301697731018,
#     'Text': 'upper respiratory infection',
#     'Category': 'MEDICAL_CONDITION',
#     'Type': 'DX_NAME',
#     'Traits': [{'Name': 'DIAGNOSIS', 'Score': 0.9039086103439331}],
#     'Attributes': [{'Type': 'DIRECTION',
#       'Score': 0.9793168902397156,
#       'RelationshipScore': 0.9317284822463989,
#       'RelationshipType': 'DIRECTION',
#       'Id': 0,
#       'BeginOffset': 0,
#       'EndOffset': 5,
#       'Text': 'upper',
#       'Category': 'ANATOMY',
#       'Traits': []},
#      {'Type': 'SYSTEM_ORGAN_SITE',
#       'Score': 0.371213436126709,
#       'RelationshipScore': 0.9120684266090393,
#       'RelationshipType': 'SYSTEM_ORGAN_SITE',
#       'Id': 1,
#       'BeginOffset': 6,
#       'EndOffset': 17,
#       'Text': 'respiratory',
#       'Category': 'ANATOMY',
#       'Traits': []}]},
#    {'Id': 1,
#     'BeginOffset': 6,
#     'EndOffset': 17,
#     'Score': 0.371213436126709,
#     'Text': 'respiratory',
#     'Category': 'ANATOMY',
#     'Type': 'SYSTEM_ORGAN_SITE',
#     'Traits': []},
#    {'Id': 7,
#     'BeginOffset': 29,
#     'EndOffset': 44,
#     'Score': 0.9870517253875732,
#     'Text': 'gastroenteritis',
#     'Category': 'MEDICAL_CONDITION',
#     'Type': 'DX_NAME',
#     'Traits': [{'Name': 'DIAGNOSIS', 'Score': 0.9086882472038269}]},
#    {'Id': 2,
#     'BeginOffset': 46,
#     'EndOffset': 59,
#     'Score': 0.8636285662651062,
#     'Text': 'urinary tract',
#     'Category': 'ANATOMY',
#     'Type': 'SYSTEM_ORGAN_SITE',
#     'Traits': []},
#    {'Id': 8,
#     'BeginOffset': 46,
#     'EndOffset': 69,
#     'Score': 0.9872775673866272,
#     'Text': 'urinary tract infection',
#     'Category': 'MEDICAL_CONDITION',
#     'Type': 'DX_NAME',
#     'Traits': [{'Name': 'DIAGNOSIS', 'Score': 0.9356375336647034}]},
#    {'Id': 9,
#     'BeginOffset': 71,
#     'EndOffset': 82,
#     'Score': 0.9914331436157227,
#     'Text': 'dehydration',
#     'Category': 'MEDICAL_CONDITION',
#     'Type': 'DX_NAME',
#     'Traits': [{'Name': 'DIAGNOSIS', 'Score': 0.849163293838501}]},
#    {'Id': 10,
#     'BeginOffset': 84,
#     'EndOffset': 92,
#     'Score': 0.9929355978965759,
#     'Text': 'acidosis',
#     'Category': 'MEDICAL_CONDITION',
#     'Type': 'DX_NAME',
#     'Traits': [{'Name': 'DIAGNOSIS', 'Score': 0.9404590725898743}]},
#    {'Id': 11,
#     'BeginOffset': 98,
#     'EndOffset': 112,
#     'Score': 0.36765027046203613,
#     'Text': 'viral\nsyndrome',
#     'Category': 'MEDICAL_CONDITION',
#     'Type': 'DX_NAME',
#     'Traits': [{'Name': 'DIAGNOSIS', 'Score': 0.8742738962173462}]},
#    {'Id': 13,
#     'BeginOffset': 146,
#     'EndOffset': 166,
#     'Score': 0.9838261008262634,
#     'Text': 'emergency department',
#     'Category': 'PROTECTED_HEALTH_INFORMATION',
#     'Type': 'ADDRESS',
#     'Traits': []},
#    {'Id': 14,
#     'BeginOffset': 198,
#     'EndOffset': 220,
#     'Score': 0.9990063309669495,
#     'Text': 'white blood cell count',
#     'Category': 'TEST_TREATMENT_PROCEDURE',
#     'Type': 'TEST_NAME',
#     'Traits': [],
#     'Attributes': [{'Type': 'TEST_VALUE',
#       'Score': 0.9998912811279297,
#       'RelationshipScore': 1.0,
# ...
#       'Category': 'TEST_TREATMENT_PROCEDURE',
#       'Traits': []},
#      {'Type': 'TEST_VALUE',
#       'Score': 0.9319010376930237,
#       'RelationshipScore': 0.9999996423721313,
#       'RelationshipType': 'TEST_VALUE',
#       'Id': 43,
#       'BeginOffset': 451,
#       'EndOffset': 453,
#       'Text': '22',
#       'Category': 'TEST_TREATMENT_PROCEDURE',
#       'Traits': []}]},
#    {'Id': 44,
#     'BeginOffset': 464,
#     'EndOffset': 474,
#     'Score': 0.998286783695221,
#     'Text': 'creatinine',
#     'Category': 'TEST_TREATMENT_PROCEDURE',
#     'Type': 'TEST_NAME',
#     'Traits': [],
#     'Attributes': [{'Type': 'TEST_VALUE',
#       'Score': 0.9992976188659668,
#       'RelationshipScore': 0.9999995231628418,
#       'RelationshipType': 'TEST_VALUE',
#       'Id': 45,
#       'BeginOffset': 478,
#       'EndOffset': 481,
#       'Text': '1.4',
#       'Category': 'TEST_TREATMENT_PROCEDURE',
#       'Traits': []}]},
#    {'Id': 46,
#     'BeginOffset': 483,
#     'EndOffset': 486,
#     'Score': 0.8811151385307312,
#     'Text': 'AST',
#     'Category': 'TEST_TREATMENT_PROCEDURE',
#     'Type': 'TEST_NAME',
#     'Traits': [],
#     'Attributes': [{'Type': 'TEST_VALUE',
#       'Score': 0.9319697022438049,
#       'RelationshipScore': 0.9999939203262329,
#       'RelationshipType': 'TEST_VALUE',
#       'Id': 48,
#       'BeginOffset': 500,
#       'EndOffset': 508,
#       'Text': 'elevated',
#       'Category': 'TEST_TREATMENT_PROCEDURE',
#       'Traits': []},
#      {'Type': 'TEST_VALUE',
#       'Score': 0.9427873492240906,
#       'RelationshipScore': 0.9998798370361328,
#       'RelationshipType': 'TEST_VALUE',
#       'Id': 49,
#       'BeginOffset': 519,
#       'EndOffset': 522,
#       'Text': '412',
#       'Category': 'TEST_TREATMENT_PROCEDURE',
#       'Traits': []},
#      {'Type': 'TEST_VALUE',
#       'Score': 0.9679765701293945,
#       'RelationshipScore': 0.9988266825675964,
#       'RelationshipType': 'TEST_VALUE',
#       'Id': 50,
#       'BeginOffset': 527,
#       'EndOffset': 530,
#       'Text': '180',
#       'Category': 'TEST_TREATMENT_PROCEDURE',
#       'Traits': []}]},
#    {'Id': 47,
#     'BeginOffset': 491,
#     'EndOffset': 494,
#     'Score': 0.9939768314361572,
#     'Text': 'ALT',
#     'Category': 'TEST_TREATMENT_PROCEDURE',
#     'Type': 'TEST_NAME',
#     'Traits': [],
#     'Attributes': [{'Type': 'TEST_VALUE',
#       'Score': 0.9319697022438049,
#       'RelationshipScore': 0.9999998807907104,
#       'RelationshipType': 'TEST_VALUE',
#       'Id': 48,
#       'BeginOffset': 500,
#       'EndOffset': 508,
#       'Text': 'elevated',
#       'Category': 'TEST_TREATMENT_PROCEDURE',
#       'Traits': []},
#      {'Type': 'TEST_VALUE',
#       'Score': 0.9427873492240906,
#       'RelationshipScore': 0.9997707009315491,
#       'RelationshipType': 'TEST_VALUE',
#       'Id': 49,
#       'BeginOffset': 519,
#       'EndOffset': 522,
#       'Text': '412',
#       'Category': 'TEST_TREATMENT_PROCEDURE',
#       'Traits': []},
#      {'Type': 'TEST_VALUE',
#       'Score': 0.9679765701293945,
#       'RelationshipScore': 0.9998866319656372,
#       'RelationshipType': 'TEST_VALUE',
#       'Id': 50,
#       'BeginOffset': 527,
#       'EndOffset': 530,
#       'Text': '180',
#       'Category': 'TEST_TREATMENT_PROCEDURE',
#       'Traits': []}]},
#    {'Id': 51,
#     'BeginOffset': 547,
#     'EndOffset': 562,
#     'Score': 0.7536828517913818,
#     'Text': 'cath urinalysis',
#     'Category': 'TEST_TREATMENT_PROCEDURE',
#     'Type': 'TEST_NAME',
#     'Traits': [],
#     'Attributes': [{'Type': 'TEST_VALUE',
#       'Score': 0.8730601668357849,
#       'RelationshipScore': 1.0,
#       'RelationshipType': 'TEST_VALUE',
#       'Id': 52,
#       'BeginOffset': 571,
#       'EndOffset': 592,
#       'Text': 'no signs of infection',
#       'Category': 'TEST_TREATMENT_PROCEDURE',
#       'Traits': []}]},
#    {'Id': 12,
#     'BeginOffset': 583,
#     'EndOffset': 592,
#     'Score': 0.9050097465515137,
#     'Text': 'infection',
#     'Category': 'MEDICAL_CONDITION',
#     'Type': 'DX_NAME',
#     'Traits': [{'Name': 'DIAGNOSIS', 'Score': 0.5458675622940063},
#      {'Name': 'NEGATION', 'Score': 0.7651711702346802}]},
#    {'Id': 53,
#     'BeginOffset': 594,
#     'EndOffset': 616,
#     'Score': 0.3615680932998657,
#     'Text': 'Spina fluid evaluation',
#     'Category': 'TEST_TREATMENT_PROCEDURE',
#     'Type': 'TEST_NAME',
#     'Traits': []},
#    {'Id': 54,
#     'BeginOffset': 651,
#     'EndOffset': 662,
#     'Score': 0.9974133372306824,
#     'Text': 'White count',
#     'Category': 'TEST_TREATMENT_PROCEDURE',
#     'Type': 'TEST_NAME',
#     'Traits': []},
#    {'Id': 55,
#     'BeginOffset': 666,
#     'EndOffset': 675,
#     'Score': 0.988593339920044,
#     'Text': 'red count',
#     'Category': 'TEST_TREATMENT_PROCEDURE',
#     'Type': 'TEST_NAME',
#     'Traits': [],
#     'Attributes': [{'Type': 'TEST_VALUE',
#       'Score': 0.31405383348464966,
#       'RelationshipScore': 0.9999954700469971,
#       'RelationshipType': 'TEST_VALUE',
#       'Id': 56,
#       'BeginOffset': 676,
#       'EndOffset': 680,
#       'Text': '2060',
#       'Category': 'TEST_TREATMENT_PROCEDURE',
#       'Traits': []}]},
#    {'Id': 57,
#     'BeginOffset': 682,
#     'EndOffset': 686,
#     'Score': 0.46472468972206116,
#     'Text': 'Gram',
#     'Category': 'TEST_TREATMENT_PROCEDURE',
#     'Type': 'TEST_NAME',
#     'Traits': [],
#     'Attributes': [{'Type': 'TEST_VALUE',
#       'Score': 0.9955655932426453,
#       'RelationshipScore': 0.9999997615814209,
#       'RelationshipType': 'TEST_VALUE',
#       'Id': 59,
#       'BeginOffset': 693,
#       'EndOffset': 701,
#       'Text': 'negative',
#       'Category': 'TEST_TREATMENT_PROCEDURE',
#       'Traits': []}]},
#    {'Id': 58,
#     'BeginOffset': 687,
#     'EndOffset': 692,
#     'Score': 0.8463635444641113,
#     'Text': 'stain',
#     'Category': 'TEST_TREATMENT_PROCEDURE',
#     'Type': 'TEST_NAME',
#     'Traits': [],
#     'Attributes': [{'Type': 'TEST_VALUE',
#       'Score': 0.9955655932426453,
#       'RelationshipScore': 1.0,
#       'RelationshipType': 'TEST_VALUE',
#       'Id': 59,
#       'BeginOffset': 693,
#       'EndOffset': 701,
#       'Text': 'negative',
#       'Category': 'TEST_TREATMENT_PROCEDURE',
#       'Traits': []}]},
#    {'Id': 5,
#     'BeginOffset': 929,
#     'EndOffset': 937,
#     'Score': 0.9776450395584106,
#     'Text': 'Betadine',
#     'Category': 'MEDICATION',
#     'Type': 'BRAND_NAME',
#     'Traits': []},
#    {'Id': 60,
#     'BeginOffset': 1025,
#     'EndOffset': 1042,
#     'Score': 0.9204146862030029,
#     'Text': 'L4- L5 interspace',
#     'Category': 'ANATOMY',
#     'Type': 'SYSTEM_ORGAN_SITE',
#     'Traits': []},
#    {'Id': 73,
#     'BeginOffset': 1047,
#     'EndOffset': 1059,
#     'Score': 0.4994346797466278,
#     'Text': 'anesthetized',
#     'Category': 'TEST_TREATMENT_PROCEDURE',
#     'Type': 'PROCEDURE_NAME',
#     'Traits': []},
#    {'Id': 62,
#     'BeginOffset': 1072,
#     'EndOffset': 1081,
#     'Score': 0.9433869123458862,
#     'Text': 'lidocaine',
#     'Category': 'MEDICATION',
#     'Type': 'GENERIC_NAME',
#     'Traits': [],
#     'Attributes': [{'Type': 'STRENGTH',
#       'Score': 0.9796944260597229,
#       'RelationshipScore': 0.9999772310256958,
#       'RelationshipType': 'STRENGTH',
#       'Id': 61,
#       'BeginOffset': 1069,
#       'EndOffset': 1071,
#       'Text': '1%',
#       'Category': 'MEDICATION',
#       'Traits': []},
#      {'Type': 'FORM',
#       'Score': 0.9893940091133118,
#       'RelationshipScore': 0.9999996423721313,
#       'RelationshipType': 'FORM',
#       'Id': 63,
#       'BeginOffset': 1082,
#       'EndOffset': 1090,
#       'Text': 'solution',
#       'Category': 'MEDICATION',
#       'Traits': []}]},
#    {'Id': 69,
#     'BeginOffset': 1559,
#     'EndOffset': 1567,
#     'Score': 0.9052464365959167,
#     'Text': 'acidosis',
#     'Category': 'MEDICAL_CONDITION',
#     'Type': 'DX_NAME',
#     'Traits': [{'Name': 'DIAGNOSIS', 'Score': 0.7667088508605957}]},
#    {'Id': 65,
#     'BeginOffset': 1628,
#     'EndOffset': 1641,
#     'Score': 0.9996713399887085,
#     'Text': 'normal saline',
#     'Category': 'MEDICATION',
#     'Type': 'GENERIC_NAME',
#     'Traits': [],
#     'Attributes': [{'Type': 'FORM',
#       'Score': 0.659420907497406,
#       'RelationshipScore': 0.9998660087585449,
#       'RelationshipType': 'FORM',
#       'Id': 64,
#       'BeginOffset': 1619,
#       'EndOffset': 1624,
#       'Text': 'bolus',
#       'Category': 'MEDICATION',
#       'Traits': []},
#      {'Type': 'FORM',
#       'Score': 0.7533296942710876,
#       'RelationshipScore': 0.9840988516807556,
#       'RelationshipType': 'FORM',
#       'Id': 66,
#       'BeginOffset': 1655,
#       'EndOffset': 1660,
#       'Text': 'bolus',
#       'Category': 'MEDICATION',
#       'Traits': []}]},
#    {'Id': 67,
#     'BeginOffset': 1664,
#     'EndOffset': 1677,
#     'Score': 0.22735978662967682,
#     'Text': 'normal\nsaline',
#     'Category': 'MEDICATION',
#     'Type': 'GENERIC_NAME',
#     'Traits': [],
#     'Attributes': [{'Type': 'FORM',
#       'Score': 0.659420907497406,
#       'RelationshipScore': 0.9972805976867676,
#       'RelationshipType': 'FORM',
#       'Id': 64,
#       'BeginOffset': 1619,
#       'EndOffset': 1624,
#       'Text': 'bolus',
#       'Category': 'MEDICATION',
#       'Traits': []},
#      {'Type': 'FORM',
#       'Score': 0.7533296942710876,
#       'RelationshipScore': 0.9988881945610046,
#       'RelationshipType': 'FORM',
#       'Id': 66,
#       'BeginOffset': 1655,
#       'EndOffset': 1660,
#       'Text': 'bolus',
#       'Category': 'MEDICATION',
#       'Traits': []}]},
#    {'Id': 68,
#     'BeginOffset': 1703,
#     'EndOffset': 1705,
#     'Score': 0.5194416642189026,
#     'Text': 'D5',
#     'Category': 'MEDICATION',
#     'Type': 'GENERIC_NAME',
#     'Traits': [],
#     'Attributes': [{'Type': 'FORM',
#       'Score': 0.659420907497406,
#       'RelationshipScore': 0.5941102504730225,
#       'RelationshipType': 'FORM',
#       'Id': 64,
#       'BeginOffset': 1619,
#       'EndOffset': 1624,
#       'Text': 'bolus',
#       'Category': 'MEDICATION',
#       'Traits': []}]},
#    {'Id': 70,
#     'BeginOffset': 1842,
#     'EndOffset': 1861,
#     'Score': 0.6540307998657227,
#     'Text': 'Hospitalist Service',
#     'Category': 'PROTECTED_HEALTH_INFORMATION',
#     'Type': 'ADDRESS',
#     'Traits': []},
#    {'Id': 71,
#     'BeginOffset': 1865,
#     'EndOffset': 1869,
#     'Score': 0.1111879050731659,
#     'Text': '2326',
#     'Category': 'PROTECTED_HEALTH_INFORMATION',
#     'Type': 'ID',
#     'Traits': []},
#    {'Id': 72,
#     'BeginOffset': 1918,
#     'EndOffset': 1922,
#     'Score': 0.9789880514144897,
#     'Text': 'PICU',
#     'Category': 'PROTECTED_HEALTH_INFORMATION',
#     'Type': 'ADDRESS',
#     'Traits': []},
#    {'Id': 91,
#     'BeginOffset': 1977,
#     'EndOffset': 1986,
#     'Score': 0.36009442806243896,
#     'Text': 'IV fluids',
#     'Category': 'TEST_TREATMENT_PROCEDURE',
#     'Type': 'TREATMENT_NAME',
#     'Traits': []},
#    {'Id': 76,
#     'BeginOffset': 1980,
#     'EndOffset': 1986,
#     'Score': 0.9738315343856812,
#     'Text': 'fluids',
#     'Category': 'MEDICATION',
#     'Type': 'GENERIC_NAME',
#     'Traits': [],
#     'Attributes': [{'Type': 'ROUTE_OR_MODE',
#       'Score': 0.8729318380355835,
#       'RelationshipScore': 1.0,
#       'RelationshipType': 'ROUTE_OR_MODE',
#       'Id': 75,
#       'BeginOffset': 1977,
#       'EndOffset': 1979,
#       'Text': 'IV',
#       'Category': 'MEDICATION',
#       'Traits': []}]},
#    {'Id': 82,
#     'BeginOffset': 2005,
#     'EndOffset': 2016,
#     'Score': 0.9746622443199158,
#     'Text': 'dehydration',
#     'Category': 'MEDICAL_CONDITION',
#     'Type': 'DX_NAME',
#     'Traits': [{'Name': 'DIAGNOSIS', 'Score': 0.6946079730987549}]},
#    {'Id': 78,
#     'BeginOffset': 2035,
#     'EndOffset': 2048,
#     'Score': 0.9997512698173523,
#     'Text': 'normal saline',
#     'Category': 'MEDICATION',
#     'Type': 'GENERIC_NAME',
#     'Traits': [],
#     'Attributes': [{'Type': 'FORM',
#       'Score': 0.8128138780593872,
#       'RelationshipScore': 0.9994025230407715,
#       'RelationshipType': 'FORM',
#       'Id': 77,
#       'BeginOffset': 2026,
#       'EndOffset': 2031,
#       'Text': 'bolus',
#       'Category': 'MEDICATION',
#       'Traits': []}]},
#    {'Id': 79,
#     'BeginOffset': 2081,
#     'EndOffset': 2083,
#     'Score': 0.5191901922225952,
#     'Text': 'D5',
#     'Category': 'MEDICATION',
#     'Type': 'GENERIC_NAME',
#     'Traits': [],
#     'Attributes': [{'Type': 'FORM',
#       'Score': 0.8128138780593872,
#       'RelationshipScore': 0.9653294682502747,
#       'RelationshipType': 'FORM',
#       'Id': 77,
#       'BeginOffset': 2026,
#       'EndOffset': 2031,
#       'Text': 'bolus',
#       'Category': 'MEDICATION',
#       'Traits': []}]},
#    {'Id': 89,
#     'BeginOffset': 2136,
#     'EndOffset': 2155,
#     'Score': 0.6277776956558228,
#     'Text': 'Hospitalist Service',
#     'Category': 'PROTECTED_HEALTH_INFORMATION',
#     'Type': 'ADDRESS',
#     'Traits': []},
#    {'Id': 81,
#     'BeginOffset': 2173,
#     'EndOffset': 2179,
#     'Score': 0.967775821685791,
#     'Text': 'fluids',
#     'Category': 'MEDICATION',
#     'Type': 'GENERIC_NAME',
#     'Traits': [],
#     'Attributes': [{'Type': 'ROUTE_OR_MODE',
#       'Score': 0.8319485783576965,
#       'RelationshipScore': 1.0,
#       'RelationshipType': 'ROUTE_OR_MODE',
#       'Id': 80,
#       'BeginOffset': 2170,
#       'EndOffset': 2172,
#       'Text': 'IV',
#       'Category': 'MEDICATION',
#       'Traits': []}]},
#    {'Id': 83,
#     'BeginOffset': 2211,
#     'EndOffset': 2222,
#     'Score': 0.7219566106796265,
#     'Text': 'clear lungs',
#     'Category': 'MEDICAL_CONDITION',
#     'Type': 'DX_NAME',
#     'Traits': [{'Name': 'SIGN', 'Score': 0.6969794034957886}]},
#    {'Id': 74,
#     'BeginOffset': 2217,
#     'EndOffset': 2222,
#     'Score': 0.8235460519790649,
#     'Text': 'lungs',
#     'Category': 'ANATOMY',
#     'Type': 'SYSTEM_ORGAN_SITE',
#     'Traits': []},
#    {'Id': 84,
#     'BeginOffset': 2354,
#     'EndOffset': 2362,
#     'Score': 0.9938129186630249,
#     'Text': 'vomiting',
#     'Category': 'MEDICAL_CONDITION',
#     'Type': 'DX_NAME',
#     'Traits': [{'Name': 'SYMPTOM', 'Score': 0.7135058641433716},
#      {'Name': 'NEGATION', 'Score': 0.521385908126831}]},
#    {'Id': 85,
#     'BeginOffset': 2367,
#     'EndOffset': 2374,
#     'Score': 0.9313194155693054,
#     'Text': 'burping',
#     'Category': 'MEDICAL_CONDITION',
#     'Type': 'DX_NAME',
#     'Traits': [{'Name': 'SYMPTOM', 'Score': 0.7230430841445923}]},
#    {'Id': 86,
#     'BeginOffset': 2480,
#     'EndOffset': 2495,
#     'Score': 0.9911506175994873,
#     'Text': 'gastroenteritis',
#     'Category': 'MEDICAL_CONDITION',
#     'Type': 'DX_NAME',
#     'Traits': [{'Name': 'DIAGNOSIS', 'Score': 0.915462076663971}]},
#    {'Id': 87,
#     'BeginOffset': 2497,
#     'EndOffset': 2515,
#     'Score': 0.9339323043823242,
#     'Text': 'metabolic acidosis',
#     'Category': 'MEDICAL_CONDITION',
#     'Type': 'DX_NAME',
#     'Traits': [{'Name': 'DIAGNOSIS', 'Score': 0.9542778134346008}]},
#    {'Id': 88,
#     'BeginOffset': 2521,
#     'EndOffset': 2532,
#     'Score': 0.9741730690002441,
#     'Text': 'dehydration',
#     'Category': 'MEDICAL_CONDITION',
#     'Type': 'DX_NAME',
#     'Traits': [{'Name': 'DIAGNOSIS', 'Score': 0.8451777696609497}]},
#    {'Id': 90,
#     'BeginOffset': 2713,
#     'EndOffset': 2732,
#     'Score': 0.5483789443969727,
#     'Text': 'Hospitalist Service',
#     'Category': 'PROTECTED_HEALTH_INFORMATION',
#     'Type': 'ADDRESS',
#     'Traits': []}],
#   'UnmappedAttributes': [{'Type': 'ANATOMY',
#     'Attribute': {'Type': 'DIRECTION',
#      'Score': 0.9793168902397156,
#      'Id': 0,
#      'BeginOffset': 0,
#      'EndOffset': 5,
#      'Text': 'upper',
#      'Category': 'ANATOMY',
#      'Traits': []}},
#    {'Type': 'ANATOMY',
#     'Attribute': {'Type': 'DIRECTION',
#      'Score': 0.9258328080177307,
#      'Id': 3,
#      'BeginOffset': 889,
#      'EndOffset': 893,
#      'Text': 'left',
#      'Category': 'ANATOMY',
#      'Traits': []}},
#    {'Type': 'ANATOMY',
#     'Attribute': {'Type': 'DIRECTION',
#      'Score': 0.9387577772140503,
#      'Id': 4,
#      'BeginOffset': 894,
#      'EndOffset': 901,
#      'Text': 'lateral',
#      'Category': 'ANATOMY',
#      'Traits': []}}],
#   'ModelVersion': '1.0.0',
#   'ResponseMetadata': {'RequestId': '36137a1f-b7f4-4576-b065-603462acdb3c',
#    'HTTPStatusCode': 200,
#    'HTTPHeaders': {'x-amzn-requestid': '36137a1f-b7f4-4576-b065-603462acdb3c',
#     'content-type': 'application/x-amz-json-1.1',
#     'content-length': '19813',
#     'date': 'Sun, 06 Sep 2020 16:32:25 GMT'},
#    'RetryAttempts': 0}}]

# %%
client = boto3.client('sagemaker-runtime')

client.invoke_endpoint(
    EndpointName='string',
    Body=b'bytes'|file,
    ContentType='string',
    Accept='string',
    CustomAttributes='string',
    TargetModel='string',
    TargetVariant='string'
)
